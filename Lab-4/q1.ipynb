# %%
import numpy as np
import pandas as pd

# %%
#Method-1

x=[0.5 ,0.5 ,-0.5, -0.25 ,-0.25]
A=[[1,0.135,0.195,0.137,0.157],[0.135,1,0.2,0.309,0.143],[0.195,0.2,1,0.157,0.122],[0.137,0.309,0.157,1,0.195],[0.157,0.143,0.122,0.195,1]]
x=np.array(x)
A=np.array(A)
#print(A)

xt=np.transpose(x)
dis=np.sqrt(np.dot(np.dot(x,A),xt))
print("Quadratic form distance:",dis)

# %%
#Method-2

def quadratic_form(x_minus_y_T, matrix):
    return np.sqrt(x_minus_y_T @ matrix @ x_minus_y_T.T)

matrix = np.array(
    [
        [1, 0.135, 0.195, 0.137, 0.157],
        [0.135, 1, 0.2, 0.309, 0.143],
        [0.195, 0.2, 1, 0.157, 0.122],
        [0.137, 0.309, 0.157, 1, 0.195],
        [0.157, 0.143, 0.122, 0.195, 1]
    ]
)

hq_minus_ht_T = np.array([0.5, 0.5, -0.5, -0.25, -0.25])

dist = quadratic_form(hq_minus_ht_T, matrix)
print(f"Quadratic form distance: {dist}")
